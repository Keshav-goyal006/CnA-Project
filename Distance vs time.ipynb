# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Mumbai_train_final.csv')
df['Burden'] = df['Footfall (lakhs)']/df['Platforms']
df['Age'] = 2025 - df['Year of Opening']
k = (df['Platforms'].sum()/df.shape[0]).astype(int)
k2 = (df['Tracks'].sum()/df.shape[0]).astype(int)

df['Platforms'] = df['Platforms'].fillna(k)
df['Tracks'] = df['Tracks'].fillna(k2)
df['Distance From Previous of the Line'] = df['Distance From Previous of the Line'].replace('[KM]','',regex = True).astype(int)
df['Time taken From Previous of the Line'] = df['Time taken From Previous of the Line'].replace('[min]','',regex = True).astype(int)

# %% [markdown]
# ## Distance v/s Time Graphs
# ### >  Western Line

# %%
df1 = df[df['Line'] == 'Western']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Western Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Central 1

# %%
df1 = df[df['Line'] == 'Central 1']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Central 1 Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Central 2

# %%
df1 = df[df['Line'] == 'Central 2']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Central 2 Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Harbour

# %%
df1 = df[df['Line'] == 'Harbour']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Harbour Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Trans-Harbour

# %%
df1 = df[df['Line'] == 'Trans Harbour']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Trans Harbour Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Diva-Roha

# %%
df1 = df[df['Line'] == 'Diva-Roha']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Diva-Roha Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Uran

# %%
df1 = df[df['Line'] == 'Uran']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Uran Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Dahanu-Virar-Panvel

# %%
df1 = df[df['Line'] == 'Dahanu-Virar-Panvel']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Dahanu-Virar-Panvel Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()

# %% [markdown]
# ### > Neral-Matheran

# %%
df1 = df[df['Line'] == 'Neral-Matheran']
sns.lineplot(x = 'Time taken From Previous of the Line',y = 'Distance From Previous of the Line',data = df1,label = '',marker = 'o')
plt.xlabel('Time Taken from Previous of the Line (in mins)')
plt.title('Neral-Matheran Line in Distance v/s Time',fontdict = {'size' : 18,'family':'Serif'})
plt.grid()
plt.show()
